# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
# Import requests library, API key, time library, datetime module from datetime library

import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Build the basic URL with API key added
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | churapcha
# Processing Record 3 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | abu zabad
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | valparaiso
# Processing Record 8 of Set 1 | viedma
# Processing Record 9 of Set 1 | vaitape
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | ancud
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | bengkulu
# Processing Record 18 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 1 | vostok
# Processing Record 20 of Set 1 | ahipara
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | barcelona
# Processing Record 23 of Set 1 | ponta do sol
# Processing Record 24 of Set 1 | anzio
# Processing Record 25 of Set 1 | codrington
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | letnyaya stavka
# Processing Record 30 of Set 1 | caravelas
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | zwedru
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | camacha
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | lagoa
# Processing Record 39 of Set 1 | cabo san lucas
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | fillan
# Processing Record 43 of Set 1 | geraldton
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | palma
# Processing Record 46 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | brasilia de minas
# Processing Record 50 of Set 1 | shingu
# Processing Record 1 of Set 2 | shanhetun
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | chumikan
# Processing Record 7 of Set 2 | aklavik
# Processing Record 8 of Set 2 | santa isabel do rio negro
# Processing Record 9 of Set 2 | fairbanks
# Processing Record 10 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 11 of Set 2 | portland
# Processing Record 12 of Set 2 | onda
# Processing Record 13 of Set 2 | tual
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | santa marinella
# Processing Record 17 of Set 2 | rio grande
# Processing Record 18 of Set 2 | muros
# Processing Record 19 of Set 2 | olinda
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | jining
# Processing Record 22 of Set 2 | lompoc
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | norman wells
# Processing Record 25 of Set 2 | makakilo city
# Processing Record 26 of Set 2 | tuktoyaktuk
# Processing Record 27 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 2 | buriti bravo
# Processing Record 29 of Set 2 | nyurba
# Processing Record 30 of Set 2 | khowst
# Processing Record 31 of Set 2 | piacabucu
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | zlatoustovsk
# City not found. Skipping...
# Processing Record 34 of Set 2 | rivadavia
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | belgrade
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | agapovka
# Processing Record 39 of Set 2 | anchorage
# Processing Record 40 of Set 2 | keti bandar
# Processing Record 41 of Set 2 | aksu
# Processing Record 42 of Set 2 | sao joao da barra
# Processing Record 43 of Set 2 | oktyabrskiy
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | havoysund
# Processing Record 47 of Set 2 | pevek
# Processing Record 48 of Set 2 | namatanai
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | lavrentiya
# Processing Record 1 of Set 3 | capaci
# Processing Record 2 of Set 3 | mahebourg
# Processing Record 3 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 3 | otjimbingwe
# Processing Record 5 of Set 3 | karratha
# Processing Record 6 of Set 3 | ilulissat
# Processing Record 7 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | taree
# Processing Record 10 of Set 3 | sisimiut
# Processing Record 11 of Set 3 | los llanos de aridane
# Processing Record 12 of Set 3 | vila velha
# Processing Record 13 of Set 3 | slave lake
# Processing Record 14 of Set 3 | salalah
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | daxian
# City not found. Skipping...
# Processing Record 17 of Set 3 | neuquen
# Processing Record 18 of Set 3 | mayumba
# Processing Record 19 of Set 3 | ostrovnoy
# Processing Record 20 of Set 3 | port-cartier
# Processing Record 21 of Set 3 | margate
# Processing Record 22 of Set 3 | akyab
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 25 of Set 3 | the valley
# Processing Record 26 of Set 3 | quatre cocos
# Processing Record 27 of Set 3 | flin flon
# Processing Record 28 of Set 3 | esperance
# Processing Record 29 of Set 3 | atikokan
# Processing Record 30 of Set 3 | new norfolk
# Processing Record 31 of Set 3 | tuatapere
# Processing Record 32 of Set 3 | hobart
# Processing Record 33 of Set 3 | atasu
# Processing Record 34 of Set 3 | port macquarie
# Processing Record 35 of Set 3 | mecca
# Processing Record 36 of Set 3 | hasaki
# Processing Record 37 of Set 3 | ovsyanka
# Processing Record 38 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 39 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 3 | santiago del estero
# Processing Record 41 of Set 3 | genhe
# Processing Record 42 of Set 3 | kishi
# Processing Record 43 of Set 3 | nuuk
# Processing Record 44 of Set 3 | ilebo
# Processing Record 45 of Set 3 | vao
# Processing Record 46 of Set 3 | fortuna
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | port elizabeth
# Processing Record 49 of Set 3 | ballina
# Processing Record 50 of Set 3 | colares
# Processing Record 1 of Set 4 | georgetown
# Processing Record 2 of Set 4 | kodiak
# Processing Record 3 of Set 4 | lorengau
# Processing Record 4 of Set 4 | kangalassy
# Processing Record 5 of Set 4 | biga
# Processing Record 6 of Set 4 | spisska bela
# Processing Record 7 of Set 4 | shimoda
# Processing Record 8 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 4 | gravdal
# Processing Record 10 of Set 4 | zabaykalsk
# Processing Record 11 of Set 4 | avera
# Processing Record 12 of Set 4 | mwense
# Processing Record 13 of Set 4 | calama
# Processing Record 14 of Set 4 | shelburne
# Processing Record 15 of Set 4 | zhezkazgan
# Processing Record 16 of Set 4 | nanortalik
# Processing Record 17 of Set 4 | vestmannaeyjar
# Processing Record 18 of Set 4 | wenatchee
# Processing Record 19 of Set 4 | hoquiam
# Processing Record 20 of Set 4 | halifax
# Processing Record 21 of Set 4 | paita
# Processing Record 22 of Set 4 | port hedland
# Processing Record 23 of Set 4 | aykhal
# Processing Record 24 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 4 | irara
# Processing Record 26 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 27 of Set 4 | biak
# Processing Record 28 of Set 4 | flinders
# Processing Record 29 of Set 4 | plettenberg bay
# Processing Record 30 of Set 4 | marmora
# Processing Record 31 of Set 4 | ganzhou
# Processing Record 32 of Set 4 | berlevag
# Processing Record 33 of Set 4 | rio cuarto
# Processing Record 34 of Set 4 | longyearbyen
# Processing Record 35 of Set 4 | constitucion
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | dwarka
# Processing Record 38 of Set 4 | belmonte
# Processing Record 39 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 4 | pahrump
# Processing Record 41 of Set 4 | andapa
# Processing Record 42 of Set 4 | cairns
# Processing Record 43 of Set 4 | bogorodskoye
# Processing Record 44 of Set 4 | cururupu
# Processing Record 45 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 46 of Set 4 | zhoucheng
# Processing Record 47 of Set 4 | mabai
# Processing Record 48 of Set 4 | neka
# Processing Record 49 of Set 4 | saldanha
# Processing Record 50 of Set 4 | guerrero negro
# Processing Record 1 of Set 5 | griffith
# Processing Record 2 of Set 5 | pacific grove
# Processing Record 3 of Set 5 | lasa
# Processing Record 4 of Set 5 | tanout
# Processing Record 5 of Set 5 | manono
# Processing Record 6 of Set 5 | tura
# Processing Record 7 of Set 5 | otane
# Processing Record 8 of Set 5 | independence
# Processing Record 9 of Set 5 | souillac
# Processing Record 10 of Set 5 | poum
# Processing Record 11 of Set 5 | port perry
# Processing Record 12 of Set 5 | saskylakh
# Processing Record 13 of Set 5 | nokaneng
# Processing Record 14 of Set 5 | yairipok
# Processing Record 15 of Set 5 | wanaka
# Processing Record 16 of Set 5 | hithadhoo
# Processing Record 17 of Set 5 | glen cove
# Processing Record 18 of Set 5 | oussouye
# Processing Record 19 of Set 5 | josefina
# Processing Record 20 of Set 5 | namibe
# Processing Record 21 of Set 5 | ninohe
# Processing Record 22 of Set 5 | xuanhua
# Processing Record 23 of Set 5 | kotaparh
# Processing Record 24 of Set 5 | idah
# Processing Record 25 of Set 5 | pepperell
# Processing Record 26 of Set 5 | bara
# Processing Record 27 of Set 5 | cayenne
# Processing Record 28 of Set 5 | kutum
# Processing Record 29 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 5 | provideniya
# Processing Record 31 of Set 5 | malpura
# Processing Record 32 of Set 5 | baiao
# Processing Record 33 of Set 5 | talcahuano
# Processing Record 34 of Set 5 | bambanglipuro
# Processing Record 35 of Set 5 | jambi
# Processing Record 36 of Set 5 | faanui
# Processing Record 37 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 38 of Set 5 | sao felix do xingu
# Processing Record 39 of Set 5 | sorland
# Processing Record 40 of Set 5 | carnarvon
# Processing Record 41 of Set 5 | charters towers
# Processing Record 42 of Set 5 | pontes e lacerda
# Processing Record 43 of Set 5 | udachnyy
# Processing Record 44 of Set 5 | tracy
# Processing Record 45 of Set 5 | khandbari
# Processing Record 46 of Set 5 | fort nelson
# Processing Record 47 of Set 5 | channel-port aux basques
# Processing Record 48 of Set 5 | dicabisagan
# Processing Record 49 of Set 5 | luderitz
# Processing Record 50 of Set 5 | lebu
# Processing Record 1 of Set 6 | banda aceh
# Processing Record 2 of Set 6 | kedrovyy
# Processing Record 3 of Set 6 | isangel
# Processing Record 4 of Set 6 | bambous virieux
# Processing Record 5 of Set 6 | tautira
# Processing Record 6 of Set 6 | skowhegan
# Processing Record 7 of Set 6 | saint-louis
# Processing Record 8 of Set 6 | stornoway
# Processing Record 9 of Set 6 | nsanje
# Processing Record 10 of Set 6 | puerto del rosario
# Processing Record 11 of Set 6 | nhulunbuy
# Processing Record 12 of Set 6 | hamilton
# Processing Record 13 of Set 6 | ketchikan
# Processing Record 14 of Set 6 | saint-ambroise
# Processing Record 15 of Set 6 | egvekinot
# Processing Record 16 of Set 6 | alegrete
# Processing Record 17 of Set 6 | parana
# Processing Record 18 of Set 6 | puerto escondido
# Processing Record 19 of Set 6 | chimoio
# Processing Record 20 of Set 6 | sabalgarh
# Processing Record 21 of Set 6 | sao filipe
# Processing Record 22 of Set 6 | san luis
# Processing Record 23 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 24 of Set 6 | litoral del san juan
# City not found. Skipping...
# Processing Record 25 of Set 6 | tshane
# Processing Record 26 of Set 6 | clyde river
# Processing Record 27 of Set 6 | kungurtug
# Processing Record 28 of Set 6 | butaritari
# Processing Record 29 of Set 6 | weinan
# Processing Record 30 of Set 6 | kavaratti
# Processing Record 31 of Set 6 | east london
# Processing Record 32 of Set 6 | ruy barbosa
# Processing Record 33 of Set 6 | leh
# Processing Record 34 of Set 6 | canguaretama
# Processing Record 35 of Set 6 | grindavik
# Processing Record 36 of Set 6 | axim
# Processing Record 37 of Set 6 | beringovskiy
# Processing Record 38 of Set 6 | kyabram
# Processing Record 39 of Set 6 | kahului
# Processing Record 40 of Set 6 | masvingo
# Processing Record 41 of Set 6 | kruisfontein
# Processing Record 42 of Set 6 | yambio
# Processing Record 43 of Set 6 | silifke
# Processing Record 44 of Set 6 | padang
# Processing Record 45 of Set 6 | san quintin
# Processing Record 46 of Set 6 | katsuura
# Processing Record 47 of Set 6 | mragowo
# Processing Record 48 of Set 6 | cabra
# Processing Record 49 of Set 6 | maceio
# Processing Record 50 of Set 6 | arman
# Processing Record 1 of Set 7 | taoudenni
# Processing Record 2 of Set 7 | port hardy
# Processing Record 3 of Set 7 | warangal
# Processing Record 4 of Set 7 | bloemfontein
# Processing Record 5 of Set 7 | thinadhoo
# Processing Record 6 of Set 7 | laguna
# Processing Record 7 of Set 7 | ormara
# Processing Record 8 of Set 7 | puerto baquerizo moreno
# Processing Record 9 of Set 7 | kieta
# Processing Record 10 of Set 7 | xacmaz
# Processing Record 11 of Set 7 | semirom
# Processing Record 12 of Set 7 | umm lajj
# Processing Record 13 of Set 7 | kindu
# Processing Record 14 of Set 7 | manoel urbano
# Processing Record 15 of Set 7 | deputatskiy
# Processing Record 16 of Set 7 | sao joao do piaui
# Processing Record 17 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 7 | tenamaxtlan
# Processing Record 20 of Set 7 | lufilufi
# Processing Record 21 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 22 of Set 7 | edd
# Processing Record 23 of Set 7 | sarrebourg
# Processing Record 24 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 7 | tilichiki
# Processing Record 26 of Set 7 | khormuj
# City not found. Skipping...
# Processing Record 27 of Set 7 | brawley
# Processing Record 28 of Set 7 | deloraine
# Processing Record 29 of Set 7 | maloy
# Processing Record 30 of Set 7 | estelle
# Processing Record 31 of Set 7 | swift current
# Processing Record 32 of Set 7 | kulhudhuffushi
# Processing Record 33 of Set 7 | kalmunai
# Processing Record 34 of Set 7 | bingen
# Processing Record 35 of Set 7 | calabozo
# Processing Record 36 of Set 7 | balaguer
# Processing Record 37 of Set 7 | samarai
# Processing Record 38 of Set 7 | labuhan
# Processing Record 39 of Set 7 | touros
# Processing Record 40 of Set 7 | praia da vitoria
# Processing Record 41 of Set 7 | harper
# Processing Record 42 of Set 7 | formiga
# Processing Record 43 of Set 7 | skibbereen
# Processing Record 44 of Set 7 | narsaq
# Processing Record 45 of Set 7 | burgeo
# Processing Record 46 of Set 7 | sisophon
# Processing Record 47 of Set 7 | boysun
# Processing Record 48 of Set 7 | gambela
# Processing Record 49 of Set 7 | salinopolis
# Processing Record 50 of Set 7 | rosetown
# Processing Record 1 of Set 8 | walvis bay
# Processing Record 2 of Set 8 | port lincoln
# Processing Record 3 of Set 8 | tombouctou
# Processing Record 4 of Set 8 | torbay
# Processing Record 5 of Set 8 | north myrtle beach
# Processing Record 6 of Set 8 | dingle
# Processing Record 7 of Set 8 | cidreira
# Processing Record 8 of Set 8 | bassila
# Processing Record 9 of Set 8 | sungaipenuh
# Processing Record 10 of Set 8 | nandyal
# Processing Record 11 of Set 8 | san cristobal
# Processing Record 12 of Set 8 | kodinsk
# Processing Record 13 of Set 8 | guayaramerin
# Processing Record 14 of Set 8 | vanimo
# Processing Record 15 of Set 8 | varadero
# Processing Record 16 of Set 8 | lokosovo
# Processing Record 17 of Set 8 | athabasca
# Processing Record 18 of Set 8 | sidi bin nur
# Processing Record 19 of Set 8 | kaitangata
# Processing Record 20 of Set 8 | kununurra
# Processing Record 21 of Set 8 | chapais
# Processing Record 22 of Set 8 | mogadishu
# Processing Record 23 of Set 8 | ulaangom
# Processing Record 24 of Set 8 | villafranca de los barros
# Processing Record 25 of Set 8 | russell
# Processing Record 26 of Set 8 | tiarei
# Processing Record 27 of Set 8 | marystown
# Processing Record 28 of Set 8 | anadyr
# Processing Record 29 of Set 8 | lyaskelya
# Processing Record 30 of Set 8 | matagami
# Processing Record 31 of Set 8 | mamallapuram
# Processing Record 32 of Set 8 | alenquer
# Processing Record 33 of Set 8 | sitka
# Processing Record 34 of Set 8 | kushima
# Processing Record 35 of Set 8 | buala
# Processing Record 36 of Set 8 | muzhi
# Processing Record 37 of Set 8 | jacarau
# Processing Record 38 of Set 8 | bachaquero
# Processing Record 39 of Set 8 | hami
# Processing Record 40 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 8 | luanda
# Processing Record 42 of Set 8 | rock sound
# Processing Record 43 of Set 8 | talnakh
# Processing Record 44 of Set 8 | huilong
# Processing Record 45 of Set 8 | porosozero
# Processing Record 46 of Set 8 | manzhouli
# Processing Record 47 of Set 8 | amuntai
# Processing Record 48 of Set 8 | mwene-ditu
# Processing Record 49 of Set 8 | haines junction
# Processing Record 50 of Set 8 | amga
# Processing Record 1 of Set 9 | beloha
# Processing Record 2 of Set 9 | kuybysheve
# Processing Record 3 of Set 9 | gorontalo
# Processing Record 4 of Set 9 | grao mogol
# Processing Record 5 of Set 9 | petropavlovskoye
# Processing Record 6 of Set 9 | wagar
# Processing Record 7 of Set 9 | deh rawud
# City not found. Skipping...
# Processing Record 8 of Set 9 | ghanzi
# Processing Record 9 of Set 9 | chokwe
# Processing Record 10 of Set 9 | tiksi
# Processing Record 11 of Set 9 | husavik
# Processing Record 12 of Set 9 | vila franca do campo
# Processing Record 13 of Set 9 | merauke
# Processing Record 14 of Set 9 | cap malheureux
# Processing Record 15 of Set 9 | azoyu
# Processing Record 16 of Set 9 | lamu
# Processing Record 17 of Set 9 | jasper
# Processing Record 18 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 9 | artvin
# Processing Record 20 of Set 9 | arkhangelsk
# Processing Record 21 of Set 9 | sistranda
# Processing Record 22 of Set 9 | corinto
# Processing Record 23 of Set 9 | ambilobe
# Processing Record 24 of Set 9 | jaragua
# Processing Record 25 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 9 | road town
# Processing Record 29 of Set 9 | nybro
# Processing Record 30 of Set 9 | tambopata
# Processing Record 31 of Set 9 | moree
# Processing Record 32 of Set 9 | birobidzhan
# Processing Record 33 of Set 9 | inhambane
# Processing Record 34 of Set 9 | three hills
# Processing Record 35 of Set 9 | hovd
# Processing Record 36 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 9 | preobrazheniye
# Processing Record 38 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 9 | huarmey
# Processing Record 40 of Set 9 | asau
# Processing Record 41 of Set 9 | maine-soroa
# Processing Record 42 of Set 9 | taksimo
# Processing Record 43 of Set 9 | tessenderlo
# Processing Record 44 of Set 9 | tagusao
# Processing Record 45 of Set 9 | jalu
# Processing Record 46 of Set 9 | kajaani
# Processing Record 47 of Set 9 | glendive
# Processing Record 48 of Set 9 | buchanan
# Processing Record 49 of Set 9 | sur
# Processing Record 50 of Set 9 | alofi
# Processing Record 1 of Set 10 | avarua
# Processing Record 2 of Set 10 | pimentel
# Processing Record 3 of Set 10 | lieksa
# Processing Record 4 of Set 10 | tessalit
# Processing Record 5 of Set 10 | falam
# Processing Record 6 of Set 10 | yulara
# Processing Record 7 of Set 10 | rovaniemi
# Processing Record 8 of Set 10 | samoded
# Processing Record 9 of Set 10 | ambon
# Processing Record 10 of Set 10 | aden
# Processing Record 11 of Set 10 | wlodawa
# Processing Record 12 of Set 10 | bertoua
# Processing Record 13 of Set 10 | doume
# Processing Record 14 of Set 10 | san patricio
# Processing Record 15 of Set 10 | murray bridge
# Processing Record 16 of Set 10 | mount isa
# Processing Record 17 of Set 10 | necochea
# Processing Record 18 of Set 10 | zhigansk
# Processing Record 19 of Set 10 | polis
# Processing Record 20 of Set 10 | nara
# Processing Record 21 of Set 10 | winnemucca
# Processing Record 22 of Set 10 | kenai
# Processing Record 23 of Set 10 | seoul
# Processing Record 24 of Set 10 | osorno
# Processing Record 25 of Set 10 | sharqpur
# Processing Record 26 of Set 10 | ugoofaaru
# Processing Record 27 of Set 10 | urumqi
# Processing Record 28 of Set 10 | ayan
# Processing Record 29 of Set 10 | kassala
# Processing Record 30 of Set 10 | kupang
# Processing Record 31 of Set 10 | buncrana
# Processing Record 32 of Set 10 | liwan
# Processing Record 33 of Set 10 | santarem
# Processing Record 34 of Set 10 | gao
# Processing Record 35 of Set 10 | mana
# Processing Record 36 of Set 10 | puerto cabezas
# Processing Record 37 of Set 10 | saint anthony
# Processing Record 38 of Set 10 | marsh harbour
# Processing Record 39 of Set 10 | mehriz
# Processing Record 40 of Set 10 | benghazi
# Processing Record 41 of Set 10 | palora
# Processing Record 42 of Set 10 | phalombe
# Processing Record 43 of Set 10 | tamandare
# Processing Record 44 of Set 10 | bubaque
# Processing Record 45 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 10 | luena
# Processing Record 47 of Set 10 | kawalu
# Processing Record 48 of Set 10 | komsomolskiy
# Processing Record 49 of Set 10 | asahikawa
# Processing Record 50 of Set 10 | patterson
# Processing Record 1 of Set 11 | kumluca
# Processing Record 2 of Set 11 | ostersund
# Processing Record 3 of Set 11 | carballo
# Processing Record 4 of Set 11 | guane
# Processing Record 5 of Set 11 | comodoro rivadavia
# Processing Record 6 of Set 11 | borama
# City not found. Skipping...
# Processing Record 7 of Set 11 | boende
# Processing Record 8 of Set 11 | labuan
# Processing Record 9 of Set 11 | bukama
# Processing Record 10 of Set 11 | changji
# Processing Record 11 of Set 11 | verkhoyansk
# Processing Record 12 of Set 11 | tabou
# Processing Record 13 of Set 11 | tazovskiy
# Processing Record 14 of Set 11 | mareeba
# Processing Record 15 of Set 11 | soyo
# Processing Record 16 of Set 11 | dustlik
# Processing Record 17 of Set 11 | chauk
# Processing Record 18 of Set 11 | kailua
# Processing Record 19 of Set 11 | patea
# Processing Record 20 of Set 11 | mount gambier
# Processing Record 21 of Set 11 | san juan
# Processing Record 22 of Set 11 | avila
# Processing Record 23 of Set 11 | hanmer springs
# Processing Record 24 of Set 11 | ucluelet
# Processing Record 25 of Set 11 | lander
# Processing Record 26 of Set 11 | mishkino
# Processing Record 27 of Set 11 | goderich
# Processing Record 28 of Set 11 | la asuncion
# Processing Record 29 of Set 11 | groningen
# Processing Record 30 of Set 11 | fairmont
# Processing Record 31 of Set 11 | tari
# Processing Record 32 of Set 11 | paamiut
# Processing Record 33 of Set 11 | sechura
# Processing Record 34 of Set 11 | acapulco
# Processing Record 35 of Set 11 | taybad
# Processing Record 36 of Set 11 | saint george
# Processing Record 37 of Set 11 | boa vista
# Processing Record 38 of Set 11 | kayes
# Processing Record 39 of Set 11 | yabrud
# Processing Record 40 of Set 11 | orlik
# Processing Record 41 of Set 11 | yar-sale
# Processing Record 42 of Set 11 | domoni
# Processing Record 43 of Set 11 | westpunt
# City not found. Skipping...
# Processing Record 44 of Set 11 | nantucket
# Processing Record 45 of Set 11 | canton
# Processing Record 46 of Set 11 | kaohsiung
# Processing Record 47 of Set 11 | san jeronimo
# Processing Record 48 of Set 11 | alice springs
# Processing Record 49 of Set 11 | mehamn
# Processing Record 50 of Set 11 | yamada
# Processing Record 1 of Set 12 | nizwa
# Processing Record 2 of Set 12 | pachuquilla
# Processing Record 3 of Set 12 | lata
# Processing Record 4 of Set 12 | itarema
# Processing Record 5 of Set 12 | ipixuna
# Processing Record 6 of Set 12 | zainsk
# Processing Record 7 of Set 12 | half moon bay
# Processing Record 8 of Set 12 | kpandae
# Processing Record 9 of Set 12 | arlit
# Processing Record 10 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 11 of Set 12 | petawawa
# Processing Record 12 of Set 12 | zhangjiakou
# Processing Record 13 of Set 12 | kamra
# Processing Record 14 of Set 12 | poykovskiy
# Processing Record 15 of Set 12 | richards bay
# Processing Record 16 of Set 12 | klaksvik
# Processing Record 17 of Set 12 | kysyl-syr
# Processing Record 18 of Set 12 | ranong
# Processing Record 19 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 12 | chachoengsao
# Processing Record 21 of Set 12 | evensk
# Processing Record 22 of Set 12 | costa rica
# Processing Record 23 of Set 12 | adeje
# Processing Record 24 of Set 12 | raudeberg
# Processing Record 25 of Set 12 | la ronge
# Processing Record 26 of Set 12 | arrifes
# Processing Record 27 of Set 12 | brae
# Processing Record 28 of Set 12 | usinsk
# Processing Record 29 of Set 12 | college
# Processing Record 30 of Set 12 | leningradskiy
# Processing Record 31 of Set 12 | negru voda
# Processing Record 32 of Set 12 | shubarkuduk
# Processing Record 33 of Set 12 | malatya
# Processing Record 34 of Set 12 | ozernovskiy
# Processing Record 35 of Set 12 | ontario
# Processing Record 36 of Set 12 | coihaique
# Processing Record 37 of Set 12 | senanga
# Processing Record 38 of Set 12 | jacareacanga
# Processing Record 39 of Set 12 | tarko-sale
# Processing Record 40 of Set 12 | north bend
# Processing Record 41 of Set 12 | saint-paul
# Processing Record 42 of Set 12 | tomatlan
# Processing Record 43 of Set 12 | kangaatsiaq
# Processing Record 44 of Set 12 | santa vitoria do palmar
# Processing Record 45 of Set 12 | cuamba
# Processing Record 46 of Set 12 | fare
# Processing Record 47 of Set 12 | lerwick
# Processing Record 48 of Set 12 | surt
# Processing Record 49 of Set 12 | darab
# Processing Record 50 of Set 12 | asfi
# Processing Record 1 of Set 13 | deer lake
# Processing Record 2 of Set 13 | sheltozero
# Processing Record 3 of Set 13 | bardiyah
# Processing Record 4 of Set 13 | jacmel
# Processing Record 5 of Set 13 | pisco
# Processing Record 6 of Set 13 | takoradi
# Processing Record 7 of Set 13 | launceston
# Processing Record 8 of Set 13 | iqaluit
# Processing Record 9 of Set 13 | maua
# Processing Record 10 of Set 13 | iksal
# Processing Record 11 of Set 13 | mundo nuevo
# Processing Record 12 of Set 13 | mlonggo
# Processing Record 13 of Set 13 | andahuaylas
# Processing Record 14 of Set 13 | mmabatho
# Processing Record 15 of Set 13 | beyneu
# Processing Record 16 of Set 13 | champerico
# Processing Record 17 of Set 13 | omboue
# Processing Record 18 of Set 13 | lulea
# Processing Record 19 of Set 13 | dombas
# Processing Record 20 of Set 13 | singleton
# Processing Record 21 of Set 13 | colinas
# Processing Record 22 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 13 | rosbach
# Processing Record 24 of Set 13 | mezhova
# Processing Record 25 of Set 13 | coahuayana
# Processing Record 26 of Set 13 | hambantota
# Processing Record 27 of Set 13 | sardarshahr
# Processing Record 28 of Set 13 | el tigre
# Processing Record 29 of Set 13 | hay river
# Processing Record 30 of Set 13 | mildura
# Processing Record 31 of Set 13 | pangnirtung
# Processing Record 32 of Set 13 | barreirinha
# Processing Record 33 of Set 13 | tecoanapa
# Processing Record 34 of Set 13 | kudat
# Processing Record 35 of Set 13 | wahiawa
# Processing Record 36 of Set 13 | wiarton
# Processing Record 37 of Set 13 | chardara
# Processing Record 38 of Set 13 | nishihara
# Processing Record 39 of Set 13 | ixtapa
# Processing Record 40 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 41 of Set 13 | saint-pierre
# Processing Record 42 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 13 | dudinka
# Processing Record 44 of Set 13 | broken hill
# Processing Record 45 of Set 13 | divnogorsk
# Processing Record 46 of Set 13 | thanesar
# Processing Record 47 of Set 13 | polovinnoye
# Processing Record 48 of Set 13 | naze
# Processing Record 49 of Set 13 | binzhou
# Processing Record 50 of Set 13 | krasnyy chikoy
# Processing Record 1 of Set 14 | grimstad
# Processing Record 2 of Set 14 | baykit
# Processing Record 3 of Set 14 | nemuro
# Processing Record 4 of Set 14 | zhanakorgan
# Processing Record 5 of Set 14 | bonavista
# Processing Record 6 of Set 14 | baker city
# Processing Record 7 of Set 14 | bilma
# Processing Record 8 of Set 14 | skjervoy
# Processing Record 9 of Set 14 | maumere
# Processing Record 10 of Set 14 | moranbah
# Processing Record 11 of Set 14 | porto santo
# Processing Record 12 of Set 14 | roros
# Processing Record 13 of Set 14 | sheopur
# Processing Record 14 of Set 14 | arawa
# Processing Record 15 of Set 14 | mandalgovi
# Processing Record 16 of Set 14 | quepos
# Processing Record 17 of Set 14 | miyazu
# Processing Record 18 of Set 14 | finschhafen
# Processing Record 19 of Set 14 | araouane
# Processing Record 20 of Set 14 | kyzyl-suu
# Processing Record 21 of Set 14 | bijie
# Processing Record 22 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 23 of Set 14 | smithers
# Processing Record 24 of Set 14 | barahona
# Processing Record 25 of Set 14 | chernyshevskiy
# Processing Record 26 of Set 14 | rio tercero
# Processing Record 27 of Set 14 | chara
# Processing Record 28 of Set 14 | cockburn town
# Processing Record 29 of Set 14 | znamenskoye
# Processing Record 30 of Set 14 | lethem
# Processing Record 31 of Set 14 | porcia
# Processing Record 32 of Set 14 | agadez
# Processing Record 33 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 14 | pontiac
# Processing Record 35 of Set 14 | sun valley
# Processing Record 36 of Set 14 | saint-leu
# Processing Record 37 of Set 14 | alta floresta
# Processing Record 38 of Set 14 | poopo
# Processing Record 39 of Set 14 | te anau
# Processing Record 40 of Set 14 | ratnagiri
# Processing Record 41 of Set 14 | khani
# Processing Record 42 of Set 14 | nome
# Processing Record 43 of Set 14 | magangue
# Processing Record 44 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 45 of Set 14 | kokkola
# Processing Record 46 of Set 14 | gopalpur
# Processing Record 47 of Set 14 | dunedin
# Processing Record 48 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 14 | eydhafushi
# Processing Record 1 of Set 15 | roald
# Processing Record 2 of Set 15 | tiznit
# Processing Record 3 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 4 of Set 15 | raahe
# Processing Record 5 of Set 15 | rieti
# Processing Record 6 of Set 15 | suleja
# Processing Record 7 of Set 15 | saint-joseph
# Processing Record 8 of Set 15 | llandrindod wells
# Processing Record 9 of Set 15 | conchas
# Processing Record 10 of Set 15 | dawson creek
# Processing Record 11 of Set 15 | bonthe
# Processing Record 12 of Set 15 | pitimbu
# Processing Record 13 of Set 15 | devarkonda
# Processing Record 14 of Set 15 | kloulklubed
# Processing Record 15 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 16 of Set 15 | la ermita
# Processing Record 17 of Set 15 | nikel
# Processing Record 18 of Set 15 | playas
# Processing Record 19 of Set 15 | itoman
# Processing Record 20 of Set 15 | rawson
# Processing Record 21 of Set 15 | mugumu
# Processing Record 22 of Set 15 | broome
# Processing Record 23 of Set 15 | roma
# Processing Record 24 of Set 15 | dongying
# Processing Record 25 of Set 15 | tabory
# Processing Record 26 of Set 15 | waddan
# Processing Record 27 of Set 15 | yatou
# Processing Record 28 of Set 15 | dubbo
# Processing Record 29 of Set 15 | esso
# Processing Record 30 of Set 15 | manakara
# Processing Record 31 of Set 15 | tamale
# Processing Record 32 of Set 15 | cookshire
# City not found. Skipping...
# Processing Record 33 of Set 15 | bindi
# Processing Record 34 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 35 of Set 15 | mahibadhoo
# Processing Record 36 of Set 15 | shubarshi
# Processing Record 37 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 15 | grand gaube
# Processing Record 39 of Set 15 | westport
# Processing Record 40 of Set 15 | kyshtovka
# Processing Record 41 of Set 15 | sciacca
# Processing Record 42 of Set 15 | gat
# Processing Record 43 of Set 15 | xuanzhou
# Processing Record 44 of Set 15 | vanavara
# Processing Record 45 of Set 15 | cortes
# Processing Record 46 of Set 15 | baruun-urt
# Processing Record 47 of Set 15 | benguela
# Processing Record 48 of Set 15 | port augusta
# Processing Record 49 of Set 15 | sondershausen
# Processing Record 50 of Set 15 | nyakahanga
# Processing Record 1 of Set 16 | ilo
# Processing Record 2 of Set 16 | homer
# Processing Record 3 of Set 16 | matara
# Processing Record 4 of Set 16 | batetskiy
# Processing Record 5 of Set 16 | chubbuck
# Processing Record 6 of Set 16 | petatlan
# Processing Record 7 of Set 16 | auki
# Processing Record 8 of Set 16 | yumen
# Processing Record 9 of Set 16 | inirida
# Processing Record 10 of Set 16 | punta alta
# Processing Record 11 of Set 16 | tarakan
# Processing Record 12 of Set 16 | miri
# Processing Record 13 of Set 16 | biloela
# Processing Record 14 of Set 16 | derzhavinsk
# Processing Record 15 of Set 16 | bilibino
# Processing Record 16 of Set 16 | iwaki
# Processing Record 17 of Set 16 | magdalena
# Processing Record 18 of Set 16 | sulangan
# Processing Record 19 of Set 16 | nirgua
# Processing Record 20 of Set 16 | naryan-mar
# Processing Record 21 of Set 16 | qaqortoq
# Processing Record 22 of Set 16 | golspie
# Processing Record 23 of Set 16 | magadan
# Processing Record 24 of Set 16 | rafai
# Processing Record 25 of Set 16 | neryungri
# Processing Record 26 of Set 16 | waipawa
# Processing Record 27 of Set 16 | ilave
# Processing Record 28 of Set 16 | kisangani
# Processing Record 29 of Set 16 | wellington
# Processing Record 30 of Set 16 | union
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea -23.1203 -134.9692     72.77        74           6
# 1     Churapcha  62.0025  132.4325     42.58        85         100
# 2         Kapaa  22.0752 -159.3190     84.11        72          16
# 3     Abu Zabad  12.3500   29.2500     73.96        82         100
# 4    Valparaiso -33.0393  -71.6273     57.00        91         100
# 5        Viedma -40.8135  -62.9967     48.22        76         100
# 6       Vaitape -16.5167 -151.7500     78.24        74           9
# 7         Bluff -46.6000  168.3333     45.81        69          91
# 8         Ancud -41.8697  -73.8203     43.23        85          98
# 9  Punta Arenas -53.1500  -70.9167     41.11        60         100
#
#    Wind Speed Country Current Description
# 0       23.94      PF           clear sky
# 1       13.76      RU          light rain
# 2        5.01      US          few clouds
# 3        7.74      SD     overcast clouds
# 4       11.50      CL     overcast clouds
# 5       17.98      AR       moderate rain
# 6       21.12      PF           clear sky
# 7        2.51      NZ     overcast clouds
# 8       10.00      CL     overcast clouds
# 9       11.07      CL     overcast clouds

# %%
# Re-order columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea      PF -23.1203 -134.9692     72.77        74           6
# 1     Churapcha      RU  62.0025  132.4325     42.58        85         100
# 2         Kapaa      US  22.0752 -159.3190     84.11        72          16
# 3     Abu Zabad      SD  12.3500   29.2500     73.96        82         100
# 4    Valparaiso      CL -33.0393  -71.6273     57.00        91         100
# 5        Viedma      AR -40.8135  -62.9967     48.22        76         100
# 6       Vaitape      PF -16.5167 -151.7500     78.24        74           9
# 7         Bluff      NZ -46.6000  168.3333     45.81        69          91
# 8         Ancud      CL -41.8697  -73.8203     43.23        85          98
# 9  Punta Arenas      CL -53.1500  -70.9167     41.11        60         100
#
#    Wind Speed Current Description
# 0       23.94           clear sky
# 1       13.76          light rain
# 2        5.01          few clouds
# 3        7.74     overcast clouds
# 4       11.50     overcast clouds
# 5       17.98       moderate rain
# 6       21.12           clear sky
# 7        2.51     overcast clouds
# 8       10.00     overcast clouds
# 9       11.07     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
